# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-56634f6e-cfe6-4f61-8902-6b8d8ca10c79" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-56634f6e-cfe6-4f61-8902-6b8d8ca10c79">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving MSFT.csv to MSFT.csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
plt.style.use('fivethirtyeight')

data = pd.read_csv("MSFT.csv")
print(data.head())
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2021-04-09  252.869995  255.990005  252.440002  255.850006  253.782837
# 1  2021-04-12  254.710007  257.670013  254.619995  255.910004  253.842346
# 2  2021-04-13  257.260010  259.190002  256.829987  258.489990  256.401520
# 3  2021-04-14  257.480011  258.829987  255.160004  255.589996  253.524933
# 4  2021-04-15  257.929993  259.929993  257.730011  259.500000  257.403351
#
#      Volume
# 0  24326800
# 1  27148700
# 2  23837500
# 3  23070900
# 4  25627500

# %%
plt.figure(figsize=(10, 4))
plt.title("Microsoft Stock Prices")
plt.xlabel("Date")
plt.ylabel("Close")
plt.plot(data["Close"])
plt.show()

# %%
print(data.corr())
sns.heatmap(data.corr())
plt.show()
# Out:
#                Open      High       Low     Close  Adj Close    Volume
# Open       1.000000  0.996232  0.994796  0.989645   0.989696  0.102657
# High       0.996232  1.000000  0.993817  0.995013   0.995455  0.131502
# Low        0.994796  0.993817  1.000000  0.994689   0.994063  0.044320
# Close      0.989645  0.995013  0.994689  1.000000   0.999823  0.088054
# Adj Close  0.989696  0.995455  0.994063  0.999823   1.000000  0.095593
# Volume     0.102657  0.131502  0.044320  0.088054   0.095593  1.000000

# %%
x = data[["Open", "High", "Low"]]
y = data["Close"]
x = x.to_numpy()
y = y.to_numpy()
y = y.reshape(-1, 1)

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
model.fit(xtrain, ytrain)
ypred = model.predict(xtest)
data = pd.DataFrame(data={"Predicted Rate": ypred})
print(data.head())
# Out:
#    Predicted Rate
# 0      315.410004
# 1      260.899994
# 2      286.220001
# 3      308.130005
# 4      295.709991
